# %%
import pandas as pd
import seaborn as sns

# %%
data= pd.read_csv('E:\\epsilon\\8\\50ulke.csv')

# %%
data.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
sns.distplot(data['National Income'])

# %% [markdown]
# National incom has Rigth Skewnees

# %%
sns.distplot(data['Growth'])

# %% [markdown]
# groth has symmetric skewnees

# %%
sns.jointplot(x='Growth',y='National Income',data=data)

# %%
sns.boxplot(x='Continent',y='National Income', data=data)

# %% [markdown]
# This figure shows that North america Countries have biggest National Income then Europe then Asia then South America then Africa then Oceania

# %%
sns.boxplot(x='Continent',y='Growth', data=data)

# %% [markdown]
# This figure shows that Asia Countries have biggest Growth then Africa then Europe then South America then North america then Oceania

# %%
sns.violinplot(x='Continent',y='Growth', data=data)

# %% [markdown]
# This figure similar to boxplot, but this figure show the probability denisty of the Growth

# %%
sns.violinplot(x='Continent',y='National Income', data=data)

# %% [markdown]
#  This figure similar to boxplot, but this figure show the probability denisty of the National Income

# %%
sns.swarmplot(x='Continent',y='National Income',data=data)

# %% [markdown]
# This figure shows the density of the National Income on All Continents

# %%
sns.swarmplot(x='Continent',y='Growth',data=data)

# %% [markdown]
# This figure shows the density of the Growth on All Continents

# %%
sns.countplot(data['Continent'])

# %% [markdown]
# This figure shows the number of countries in each continent

# %%
data.corr()
# Out:
#                  Unnamed: 0  National Income    Growth  Per person
# Unnamed: 0         1.000000        -0.549732  0.261063   -0.273373
# National Income   -0.549732         1.000000  0.008961    0.159121
# Growth             0.261063         0.008961  1.000000   -0.252786
# Per person        -0.273373         0.159121 -0.252786    1.000000

# %% [markdown]
# This table shows the correlation between items

# %%
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# This figure shows the correlation between items

# %%
sns.lmplot(x='Growth',y='National Income',data=data)

# %% [markdown]
# This figure shows the relation between Growth and National Income
